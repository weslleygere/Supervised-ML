# %%
import pandas as pd

df = pd.read_csv('data/raw/data.csv')
df
# Out:
#        municipio propriedade  ponto            data_hora periodo  \
# 0        Mossoró   HARAS FVF      1  2024-08-31 12:00:00   tarde
# 1        Mossoró   HARAS FVF      1  2024-08-31 12:10:00   tarde
# 2        Mossoró   HARAS FVF      1  2024-08-31 12:20:00   tarde
# 3        Mossoró   HARAS FVF      1  2024-08-31 12:30:00   tarde
# 4        Mossoró   HARAS FVF      1  2024-08-31 12:40:00   tarde
# ...          ...         ...    ...                  ...     ...
# 137512   Mossoró      UFERSA     40  2025-01-01 18:10:00   noite
# 137513   Mossoró      UFERSA     40  2025-01-01 18:20:00   noite
# 137514   Mossoró      UFERSA     40  2025-01-01 18:30:00   noite
# 137515   Mossoró      UFERSA     40  2025-01-01 18:40:00   noite
# 137516   Mossoró      UFERSA     40  2025-01-01 18:50:00   noite
#
#          ACI_TOTAL_D  ACI_BYMIN_D  ACI_j60_total_D  ACI_j60_bymin_D    NDSI_D  \
# 0       11741.939447      3913.98      1012.583201           337.53  0.706134
# ...

# %%
df['ponto_periodo'] = df['ponto'].astype(str) + '_' + df['periodo'].astype(str)
df
# Out:
#        municipio propriedade  ponto            data_hora periodo  \
# 0        Mossoró   HARAS FVF      1  2024-08-31 12:00:00   tarde
# 1        Mossoró   HARAS FVF      1  2024-08-31 12:10:00   tarde
# 2        Mossoró   HARAS FVF      1  2024-08-31 12:20:00   tarde
# 3        Mossoró   HARAS FVF      1  2024-08-31 12:30:00   tarde
# 4        Mossoró   HARAS FVF      1  2024-08-31 12:40:00   tarde
# ...          ...         ...    ...                  ...     ...
# 137512   Mossoró      UFERSA     40  2025-01-01 18:10:00   noite
# 137513   Mossoró      UFERSA     40  2025-01-01 18:20:00   noite
# 137514   Mossoró      UFERSA     40  2025-01-01 18:30:00   noite
# 137515   Mossoró      UFERSA     40  2025-01-01 18:40:00   noite
# 137516   Mossoró      UFERSA     40  2025-01-01 18:50:00   noite
#
#          ACI_TOTAL_D  ACI_BYMIN_D  ACI_j60_total_D  ACI_j60_bymin_D    NDSI_D  \
# 0       11741.939447      3913.98      1012.583201           337.53  0.706134
# ...

# %%
df.to_csv('data/raw/data_v2.csv', index=False)

# %%
df['ponto_periodo'].nunique()
# Out:
# 141
